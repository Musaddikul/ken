# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import sklearn as sk

# %% [markdown]
# ### Import Data

# %%
credit = pd.read_csv("E:\creditcard.csv")
print(credit.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# ### Checking the number of missing values in each column

# %%
credit.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Distribution of legit transaction & fradulent transaction

# %%
credit['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
legit = credit[credit.Class == 0]
fraud = credit[credit.Class ==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ### Compare the values for both transactions

# %%
credit.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Under Sampling

# %% [markdown]
# ## Build a sample dataset containing similar distribution of normal transaction and fraudulent transaction

# %% [markdown]
# #### Number of fraudulent Transactions  -->  492

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Using cached jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython_genutils in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_contrib_core-0.4.2-py2.py3-none-any.whl
# Requirement already satisfied: jupyter_core in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Collecting jupyter_highlight_selected_word>=0.1.1 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jupyter_nbextensions_configurator>=0.4.0 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_nbextensions_configurator-0.6.3-py2.py3-none-any.whl (466 kB)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.5.4)
# Requirement already satisfied: notebook>=6.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.5.4)
# Requirement already satisfied: tornado in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (6.3.2)
# Requirement already satisfied: traitlets>=4.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (5.7.1)
# Requirement already satisfied: lxml in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions) (4.9.2)
# Requirement already satisfied: setuptools in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (68.0.0)
# Requirement already satisfied: pyyaml in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.2)
# Requirement already satisfied: bleach in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.7.0)
# Requirement already satisfied: packaging in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (305.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (8.12.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: psutil in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: backcall in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: decorator in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: colorama in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: idna>=2.8 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: executing in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Building wheels for collected packages: jupyter_contrib_nbextensions
#   Building wheel for jupyter_contrib_nbextensions (setup.py): started
#   Building wheel for jupyter_contrib_nbextensions (setup.py): finished with status 'error'
#   Running setup.py clean for jupyter_contrib_nbextensions
# Failed to build jupyter_contrib_nbextensions
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [2996 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\jupyter_contrib_nbextensions
#   copying src\jupyter_contrib_nbextensions\application.py -> build\lib\jupyter_contrib_nbextensions
#   copying src\jupyter_contrib_nbextensions\install.py -> build\lib\jupyter_contrib_nbextensions
#   copying src\jupyter_contrib_nbextensions\migrate.py -> build\lib\jupyter_contrib_nbextensions
#   copying src\jupyter_contrib_nbextensions\__init__.py -> build\lib\jupyter_contrib_nbextensions
#   creating build\lib\jupyter_contrib_nbextensions\config_scripts
#   copying src\jupyter_contrib_nbextensions\config_scripts\highlight_html_cfg.py -> build\lib\jupyter_contrib_nbextensions\config_scripts
#   copying src\jupyter_contrib_nbextensions\config_scripts\highlight_latex_cfg.py -> build\lib\jupyter_contrib_nbextensions\config_scripts
#   copying src\jupyter_contrib_nbextensions\config_scripts\__init__.py -> build\lib\jupyter_contrib_nbextensions\config_scripts
#   creating build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\collapsible_headings.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\embedhtml.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\execute_time.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\exporter_inliner.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\js_highlight.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\nbTranslate.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\pp_highlighter.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\pre_codefolding.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\pre_embedimages.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\pre_pymarkdown.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\pre_svg2pdf.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\toc2.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   copying src\jupyter_contrib_nbextensions\nbconvert_support\__init__.py -> build\lib\jupyter_contrib_nbextensions\nbconvert_support
#   running egg_info
#   writing src\jupyter_contrib_nbextensions.egg-info\PKG-INFO
#   writing dependency_links to src\jupyter_contrib_nbextensions.egg-info\dependency_links.txt
#   writing entry points to src\jupyter_contrib_nbextensions.egg-info\entry_points.txt
#   writing requirements to src\jupyter_contrib_nbextensions.egg-info\requires.txt
#   writing top-level names to src\jupyter_contrib_nbextensions.egg-info\top_level.txt
#   reading manifest file 'src\jupyter_contrib_nbextensions.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files found matching '.travis.yml'
#   warning: no previously-included files found matching 'appveyor.yml'
#   warning: no previously-included files found matching 'codecov.yml'
#   warning: no previously-included files found matching 'readthedocs.yml'
#   no previously-included directories found matching 'src\jupyter_contrib_nbextensions\nbextensions\spellchecker\typo\dictionaries'
#   no previously-included directories found matching 'conda.recipe'
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '__pycache__' found anywhere in distribution
#   warning: no previously-included files matching '*.py[cod]' found anywhere in distribution
#   warning: no previously-included files matching '.git' found anywhere in distribution
#   warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
#   warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#   writing manifest file 'src\jupyter_contrib_nbextensions.egg-info\SOURCES.txt'
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.addbefore' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.addbefore' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.addbefore' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.addbefore' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.addbefore' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.autosavetime' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.autosavetime' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.autosavetime' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.autosavetime' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.autosavetime' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.autoscroll' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.autoscroll' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.autoscroll' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.autoscroll' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.autoscroll' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.cell_filter' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.cell_filter' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.cell_filter' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.cell_filter' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.cell_filter' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.code_font_size' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.code_font_size' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.code_font_size' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.code_font_size' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.code_font_size' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.code_prettify' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.code_prettify' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.code_prettify' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.code_prettify' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.code_prettify' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.codefolding' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.codefolding' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.codefolding' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.codefolding' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.codefolding' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.codemirror_mode_extensions' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.collapsible_headings' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.contrib_nbextensions_help_item' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.css_selector' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.css_selector' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.css_selector' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.css_selector' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.css_selector' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\command\build_py.py:201: _Warning: Package 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' to be distributed and are
#           already explicitly excluding 'jupyter_contrib_nbextensions.nbextensions.css_selector.css' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
# ...
#   creating build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\README.md -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\demo.gif -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\icon.png -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\jquery.tablesorter.min.js -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\main.css -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\main.js -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\tablesorter_LICENSE.txt -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\varInspector.yaml -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\var_list.py -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   copying src\jupyter_contrib_nbextensions\nbextensions\varInspector\var_list.r -> build\lib\jupyter_contrib_nbextensions\nbextensions\varInspector
#   creating build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\README.md -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\main.css -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\main.js -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\zenmode.yaml -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode
#   creating build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back1.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back11.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back12.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back2.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back21.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back22.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\back3.jpg -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\ipynblogo0.png -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   copying src\jupyter_contrib_nbextensions\nbextensions\zenmode\images\ipynblogo1.png -> build\lib\jupyter_contrib_nbextensions\nbextensions\zenmode\images
#   creating build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\collapsible_headings.tpl -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\highlighter.tpl -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\highlighter.tplx -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\inliner.tpl -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\nbextensions.tpl -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\nbextensions.tplx -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\printviewlatex.tplx -> build\lib\jupyter_contrib_nbextensions\templates
#   copying src\jupyter_contrib_nbextensions\templates\toc2.tpl -> build\lib\jupyter_contrib_nbextensions\templates
#   C:\Users\Musaddikul_Amin\musad\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions
#   copying build\lib\jupyter_contrib_nbextensions\application.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\config_scripts
#   copying build\lib\jupyter_contrib_nbextensions\config_scripts\highlight_html_cfg.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\config_scripts
#   copying build\lib\jupyter_contrib_nbextensions\config_scripts\highlight_latex_cfg.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\config_scripts
#   copying build\lib\jupyter_contrib_nbextensions\config_scripts\__init__.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\config_scripts
#   copying build\lib\jupyter_contrib_nbextensions\install.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions
#   copying build\lib\jupyter_contrib_nbextensions\migrate.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\collapsible_headings.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\embedhtml.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\execute_time.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\exporter_inliner.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\js_highlight.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\nbTranslate.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\pp_highlighter.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\pre_codefolding.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\pre_embedimages.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\pre_pymarkdown.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\pre_svg2pdf.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\toc2.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   copying build\lib\jupyter_contrib_nbextensions\nbconvert_support\__init__.py -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbconvert_support
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\addbefore
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\addbefore\addbefore.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\addbefore
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\addbefore\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\addbefore
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\addbefore\main.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\addbefore
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\addbefore\readme.md -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\addbefore
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\autosavetime
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autosavetime\autosavetime.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autosavetime
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autosavetime\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autosavetime
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autosavetime\main.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autosavetime
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autosavetime\README.md -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autosavetime
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\autoscroll
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autoscroll\autoscroll.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autoscroll
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autoscroll\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autoscroll
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autoscroll\main.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autoscroll
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\autoscroll\README.md -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\autoscroll
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\cell_filter
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\cell_filter\cell_filter.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\cell_filter
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\cell_filter\cell_filter.yml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\cell_filter
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\cell_filter\README.md -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\cell_filter
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\blockcomment-fold.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_editor.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_editor.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_firstline_folded.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_firstline_unfolded.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_indent_folded_1.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_indent_folded_2.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\codefolding_indent_unfolded.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\edit.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\firstline-fold.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\foldgutter.css -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\icon.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\magic-fold.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\magic-folded.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\magic-unfolded.png -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\main.js -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codefolding\readme.md -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codefolding
#   creating build\bdist.win-amd64\wheel\jupyter_contrib_nbextensions\nbextensions\codemirror_mode_extensions
#   copying build\lib\jupyter_contrib_nbextensions\nbextensions\codemirror_mode_extensions\codemirror_mode_extensions.yaml -> build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codemirror_mode_extensions
#   error: could not create 'build\bdist.win-amd64\wheel\.\jupyter_contrib_nbextensions\nbextensions\codemirror_mode_extensions\codemirror_mode_extensions.yaml': No such file or directory
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for jupyter_contrib_nbextensions
# ERROR: Could not build wheels for jupyter_contrib_nbextensions, which is required to install pyproject.toml-based projects

# %%
# !jupyter contrib nbextension install --user
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension console dejavu events execute fileid
# kernel kernelspec lab labextension labhub migrate nbclassic nbconvert
# nbextension notebook qtconsole run script server serverextension troubleshoot
# trust
#
# Jupyter command `jupyter-contrib` not found.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\musaddikul_amin\musad\anaconda3\lib\site-packages (23.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
sudo apt-get install python3-dev
# Out:
#   Cell In[6], line 1
#     sudo apt-get install python3-dev
#          ^
# SyntaxError: invalid syntax
